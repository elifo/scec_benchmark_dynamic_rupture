# %% [markdown]
# # Read dataframe with all points

# %%
# %matplotlib inline

import pandas as pd 

# import pickle5 as pickle
# with open(picklename, "rb") as fh:
#     df1 = pickle.load(fh)


picklename = './outputs/DF_Model1_all_stations'
df1 = pd.read_pickle(picklename)

picklename = './outputs/DF_Model2_all_stations'
df2 = pd.read_pickle(picklename)

picklename = './outputs/DF_Model3_all_stations'
df3 = pd.read_pickle(picklename)

# %%
df1
# Out:
#               name     x     y    z      r_epi      R_rup  gm50_T0p3  \
# 0     SC.st_000000 -60.0 -20.0  0.0  64.622771  48.578111   0.071684
# 1     SC.st_000001 -60.0 -19.0  0.0  64.320312  48.175024   0.071473
# 2     SC.st_000002 -60.0 -18.0  0.0  64.032043  47.789464   0.072571
# 3     SC.st_000003 -60.0 -17.0  0.0  63.758156  47.421861   0.072546
# 4     SC.st_000004 -60.0 -16.0  0.0  63.498839  47.072634   0.071022
# ...            ...   ...   ...  ...        ...        ...        ...
# 4956  SC.st_004956  60.0  16.0  0.0  60.696808  44.570842   0.042557
# 4957  SC.st_004957  60.0  17.0  0.0  60.968045  44.939515   0.042542
# 4958  SC.st_004958  60.0  18.0  0.0  61.254408  45.327254   0.043396
# 4959  SC.st_004959  60.0  19.0  0.0  61.555686  45.733576   0.044931
# 4960  SC.st_004960  60.0  20.0  0.0  61.871662  46.157990   0.048102
#
#       gm50_T0p4  gm50_T0p5  gm50_T0p75  gm50_T1p0  gm50_T2p0  gm50_T3p0  \
# ...

# %% [markdown]
# ## Quick plots

# %% [markdown]
# ### Model 1

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))

df = df1

plt.subplot(131)
plt.scatter(df['R_rup'], df['gm50_T0p5'], c='darkturquoise', ec='snow', alpha=0.9, lw=0.5, s=50)
plt.xlabel('JB distance (km)')
plt.ylabel('GMROTD50')
plt.title('0.5 s')

plt.subplot(132)
plt.scatter(df['R_rup'], df['gm50_T1p0'], c='pink', ec='snow', alpha=0.9, lw=0.5, s=50)
plt.xlabel('JB distance (km)')
plt.ylabel('GMROTD50')
plt.title('1 s')

plt.subplot(133)
plt.scatter(df['R_rup'], df['gm50_T3p0'], c='peru', ec='snow', alpha=0.9, lw=0.5, s=50)
plt.xlabel('JB distance (km)')
plt.ylabel('GMROTD50')
plt.title('3 s')

plt.tight_layout()

# %% [markdown]
# ### Model 2

# %%
plt.figure(figsize=(10,4))

df = df2

plt.subplot(131)
plt.scatter(df['R_rup'], df['gm50_T0p5'], c='darkturquoise', ec='snow', alpha=0.9, lw=0.5, s=50)
plt.xlabel('JB distance (km)')
plt.ylabel('GMROTD50')
plt.title('0.5 s')

plt.subplot(132)
plt.scatter(df['R_rup'], df['gm50_T1p0'], c='pink', ec='snow', alpha=0.9, lw=0.5, s=50)
plt.xlabel('JB distance (km)')
plt.ylabel('GMROTD50')
plt.title('1 s')

plt.subplot(133)
plt.scatter(df['R_rup'], df['gm50_T3p0'], c='peru', ec='snow', alpha=0.9, lw=0.5, s=50)
plt.xlabel('JB distance (km)')
plt.ylabel('GMROTD50')
plt.title('3 s')

plt.tight_layout()

# %% [markdown]
# ### Model 3

# %%
plt.figure(figsize=(10,4))

df = df3

plt.subplot(131)
plt.scatter(df['R_rup'], df['gm50_T0p5'], c='darkturquoise', ec='snow', alpha=0.9, lw=0.5, s=50)
plt.xlabel('JB distance (km)')
plt.ylabel('GMROTD50')
plt.title('0.5 s')

plt.subplot(132)
plt.scatter(df['R_rup'], df['gm50_T1p0'], c='pink', ec='snow', alpha=0.9, lw=0.5, s=50)
plt.xlabel('JB distance (km)')
plt.ylabel('GMROTD50')
plt.title('1 s')

plt.subplot(133)
plt.scatter(df['R_rup'], df['gm50_T3p0'], c='peru', ec='snow', alpha=0.9, lw=0.5, s=50)
plt.xlabel('JB distance (km)')
plt.ylabel('GMROTD50')
plt.title('3 s')

plt.tight_layout()
